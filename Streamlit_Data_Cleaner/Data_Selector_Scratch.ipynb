# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Python\Files\whiskey_data_06-08-2024_grouped.csv')
df
# Out:
#                   Barcode                                  title  \
# 0      (01)42511156164165  The Nine Springs Port Wine Cask No. 1
# 1                       -                          Coillmór 2010
# 2                       -                  Craigellachie 2013 RS
# 3         0 047728 629465                  Kochertal Whisky 2015
# 4         0 27724 33750 2              St. George Spirits Lot 22
# ...                   ...                                    ...
# 30889                  no                   Glentauchers 2007 Wy
# 30890         not visible                  Tullamore Dew Phoenix
# 30891                ohne   Hellinger 70 Jahre SG Dynamo Dresden
# 30892             without                   Aberlour 08-year-old
# 30893       |747020671512                     North Port 1981 GM
#
#                               Distillery       category  \
# 0      Number Nine Spirituosenmanufaktur        Germany
# 1                        Brennerei Liebl        Germany
# ...

# %%
df_out = df[df['title'].str.contains("blanton's", case=False)]
df_out = df.query("Barcode == '80244002039'")
df_out
title_list = df['title'].tolist()
title_list = list(dict.fromkeys(title_list))
distillery_list = df['Distillery'].tolist()
distillery_list = list(dict.fromkeys(title_list))
category_list = df['category'].tolist()
category_list = list(dict.fromkeys(title_list))
series_list = df['Bottling serie'].tolist()
series_list = list(dict.fromkeys(title_list))
size_list = df['Size'].tolist()
size_list = list(dict.fromkeys(title_list))
